# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
sub = pd.read_csv('../../submissions/submission_low_snr_0.8775364899.csv')
new_sub = pd.read_csv('../../submissions/submission_with_synthetic_sample_0.8686365255.csv')
new_sub.head()
# Out:
#    segment_id  prediction
# 0        6656    0.967942
# 1        6658    0.013655
# 2        6662    0.058224
# 3        6664    0.084469
# 4        6665    0.613472

# %%
x = list(range(106))

# %%
y = sub['prediction'].values * 100
ascending_idx = np.argsort(y)

# %%
new_y = new_sub['prediction'].values * 100

# %%
plt.figure(figsize=(25, 5))
plt.plot(x, y, color='red')

# %%
plt.figure(figsize=(25, 5))
plt.plot(x, new_y, color='green')

# %%
y[y > 50] = 100
y[y <= 50] = 0

# %%
new_y[new_y > 50] = 100
new_y[new_y <= 50] = 0

# %%
plt.figure(figsize=(25, 5))
plt.plot(x, y, color='red')

# %%
plt.figure(figsize=(25, 5))
plt.plot(x, new_y, color='green')
